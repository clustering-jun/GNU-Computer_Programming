# %% [markdown]
# <a href="https://colab.research.google.com/github/clustering-jun/GNU-Computer_Programming/blob/main/L01_%EB%94%94%EC%A7%80%ED%84%B8%ED%98%81%EB%AA%85%EA%B3%BC%EC%BB%B4%ED%93%A8%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # L01. 디지털 혁명과 컴퓨터

# %% [markdown]
# ## 01. 아날로그 정보와 디지털 정보
# - 아날로그(analog)는 값들이 끊어지지 않는 연속성을 갖고 있음.
# - 디지털(digital)는 확연히 구분되는 이산적인(discrete) 값들로 표현
#
# <br>
#
# ## 02. 컴퓨터
# - 기억과 계산 등의 일을 빠르고 정확하게 처리해 주는 기계
# - 초기의 컴퓨터 의미는 '계산을수행하는장치' 라는 뜻
# - 오늘날의 컴퓨터는 계산 이외의 여러 가지 일들을 처리 해주는 범용의 기계로써 의미가 확대됨
#
# - 초기의 컴퓨터, 에니악(ENIAC): 약 30톤 무게의 계산기
#
# <br>
#
# ### 02-1. 컴퓨터 시스템의 구성
# - 하드웨어: 전자회로와 그 밖의 물리적인 장치들
# - 소프트웨어: 하드웨어를 동작시키는 프로그램 또는 관련 기술들
# - 인간의 정보처리를 닮은 컴퓨터의 정보처리
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 컴퓨터 시스템의 하드웨어
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <br>
# <br>
#
# ## 02. 추가적인 필기
#
# ### 02-1. 컴파일러와 인터프리터
# - 뭐라뭐라
#
# <br>
#
# ### 02-2. 폰노이만 아키텍처
# - 뭐라뭐라
#
# <br>
#
# ### 03-3. 컴퓨터 시스템의 동작과정 예시
# - 뭐라뭐라
